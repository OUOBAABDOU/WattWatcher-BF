# %% [markdown]
# # Analyse exploratoire des coupures d'électricité

# %%
import pandas as pd
df = pd.read_csv('../data/final/dataset_coupures_2020_2026.csv')
df.head()

# %%
df.groupby('region').size().sort_values(ascending=False)
